# %% [markdown]
# # 安装前置

# %%
# !sudo apt install libpython3.8-dev libcairo2 libcairo2-dev -y
# !sudo pip install numpy==1.22 matplotlib
# !sudo pip install https://github.com/nnsvs/nnsvs/tarball/master
# !sudo pip install https://github.com/MattShannon/bandmat/archive/master.zip wheel numpy cython==0.29.27 optuna "hydra-core >= 1.1.0, < 1.2.0" "hydra_colorlog >= 1.1.0" hydra-optuna-sweeper mlflow utaupy tqdm pydub pyyaml natsort github-clone tbb torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu113

# %% [markdown]
# # 克隆NNSVS训练套件

# %%
# !git clone https://github.com/Erythrocyte3803/enunu_training_kit.git ETK

# %% [markdown]
# # 复制歌唱数据集到指定目录

# %%
singer = 'nnsvs-test'
# !rm ./ETK/singing_database/*
# !rm ./ETK/data/*
# !cp ../input/$singer/* ./ETK/singing_database

# %% [markdown]
# # 开始训练

# %%
# !cd ./ETK/train && sudo bash run.sh --stage 0 --stop_stage 5
# !cd ./ETK/train && sudo bash run.sh --stage 12 --stop_stage 12
# !rm -f /ETK/train/release/unnamed_---/exp/unnamed_dyvaux_notebook/*/checkpoint*
# !rm -f /ETK/train/release/unnamed_---/exp/unnamed_dyvaux_notebook/*/epoch*

# %% [markdown]
# # 准备下载

# %%
# !zip -r model.zip ./ETK/train/exp/unnamed_dyvaux_notebook

# %% [markdown]
# # 下载完成

# %%
# !rm model.zip
# !rm -rf ./ETK/train/exp/unnamed_dyvaux_notebook
# !rm -rf ./ETK/train/release
