# %% [markdown]
# # 安装前置

# %%
# !sudo apt install libpython3.8-dev libcairo2 libcairo2-dev -y
# !sudo pip install numpy==1.22
# !sudo pip install https://github.com/nnsvs/nnsvs/tarball/master
# !sudo pip install https://github.com/MattShannon/bandmat/archive/master.zip wheel numpy cython==0.29.27 optuna "hydra-core >= 1.1.0, < 1.2.0" "hydra_colorlog >= 1.1.0" hydra-optuna-sweeper mlflow utaupy tqdm pydub pyyaml natsort github-clone tbb torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu113

# %% [markdown]
# # 克隆NNSVS训练套件

# %%
# !git clone https://github.com/Erythrocyte3803/enunu_training_kit.git
# Out:
# Cloning into 'enunu_training_kit'...
# remote: Enumerating objects: 454, done.
# remote: Counting objects: 100% (107/107), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 454 (delta 75), reused 79 (delta 63), pack-reused 347
# Receiving objects: 100% (454/454), 125.35 KiB | 725.00 KiB/s, done.
# Resolving deltas: 100% (242/242), done.

# %% [markdown]
# # 复制歌唱数据集到指定目录

# %%
singer = 'nnsvs-test'
# !cp ../input/$singer/* ./enunu_training_kit/train/singing_database

# %% [markdown]
# # 开始训练

# %%
# !sudo bash ./enunu_training_kit/train/run.sh
# Out:
# ./enunu_training_kit/train/run.sh: line 29: nnsvs_shell_scripts/yaml_parser.sh: No such file or directory

# %% [markdown]
# # 准备下载

# %%
# !zip -r model.zip ./enunu_training_kit/train/singing_database/exp
# Out:
# 	zip warning: name not matched: ./enunu_training_kit/train/singing_database/exp
#
# zip error: Nothing to do! (try: zip -r model.zip . -i ./enunu_training_kit/train/singing_database/exp)

# %% [markdown]
# # 下载完成

# %%
# !rm model.zip
# Out:
# rm: cannot remove 'model.zip': No such file or directory
