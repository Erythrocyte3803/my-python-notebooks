# %% [markdown]
# # 安装前置

# %%
# !sudo apt install libpython3.8-dev libcairo2 libcairo2-dev -y
# !sudo pip install https://github.com/nnsvs/nnsvs/tarball/master
# !sudo pip install https://github.com/MattShannon/bandmat/archive/master.zip wheel numpy cython==0.29.27 optuna "hydra-core >= 1.1.0, < 1.2.0" "hydra_colorlog >= 1.1.0" hydra-optuna-sweeper mlflow utaupy tqdm pydub pyyaml natsort github-clone tbb torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu113
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libcairo2 is already the newest version (1.16.0-4ubuntu1).
# libcairo2 set to manually installed.
# The following additional packages will be installed:
#   libblkid-dev libcairo-script-interpreter2 libexpat1-dev libffi-dev
#   libfontconfig1-dev libglib2.0-dev libglib2.0-dev-bin libice-dev liblzo2-2
#   libmount-dev libpcre16-3 libpcre2-16-0 libpcre2-32-0 libpcre2-dev
#   libpcre2-posix2 libpcre3 libpcre3-dev libpcre32-3 libpcrecpp0v5
#   libpixman-1-dev libpthread-stubs0-dev libpython3.8 libpython3.8-minimal
#   libpython3.8-stdlib libselinux1-dev libsepol1 libsepol1-dev libsm-dev
#   libx11-dev libxau-dev libxcb-render0-dev libxcb-shm0-dev libxcb1-dev
#   libxdmcp-dev libxext-dev libxrender-dev python3.8 python3.8-minimal uuid-dev
#   x11proto-core-dev x11proto-dev x11proto-xext-dev xorg-sgml-doctools
#   xtrans-dev
# Suggested packages:
#   libcairo2-doc libgirepository1.0-dev libglib2.0-doc libgdk-pixbuf2.0-bin
#   | libgdk-pixbuf2.0-dev libxml2-utils libice-doc libsm-doc libx11-doc
#   libxcb-doc libxext-doc python3.8-venv python3.8-doc binfmt-support
# The following NEW packages will be installed:
#   libblkid-dev libcairo-script-interpreter2 libcairo2-dev libexpat1-dev
#   libffi-dev libfontconfig1-dev libglib2.0-dev libglib2.0-dev-bin libice-dev
#   liblzo2-2 libmount-dev libpcre16-3 libpcre2-16-0 libpcre2-32-0 libpcre2-dev
#   libpcre2-posix2 libpcre3-dev libpcre32-3 libpcrecpp0v5 libpixman-1-dev
#   libpthread-stubs0-dev libpython3.8-dev libselinux1-dev libsepol1-dev
#   libsm-dev libx11-dev libxau-dev libxcb-render0-dev libxcb-shm0-dev
#   libxcb1-dev libxdmcp-dev libxext-dev libxrender-dev uuid-dev
#   x11proto-core-dev x11proto-dev x11proto-xext-dev xorg-sgml-doctools
#   xtrans-dev
# The following packages will be upgraded:
#   libpcre3 libpython3.8 libpython3.8-minimal libpython3.8-stdlib libsepol1
#   python3.8 python3.8-minimal
# 7 upgraded, 39 newly installed, 0 to remove and 36 not upgraded.
# Need to get 18.6 MB of archives.
# After this operation, 56.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpython3.8 amd64 3.8.10-0ubuntu1~20.04.5 [1625 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3.8 amd64 3.8.10-0ubuntu1~20.04.5 [387 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpython3.8-stdlib amd64 3.8.10-0ubuntu1~20.04.5 [1675 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3.8-minimal amd64 3.8.10-0ubuntu1~20.04.5 [1905 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpython3.8-minimal amd64 3.8.10-0ubuntu1~20.04.5 [717 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpcre3 amd64 2:8.39-12ubuntu0.1 [232 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsepol1 amd64 3.0-1ubuntu0.1 [252 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/main amd64 liblzo2-2 amd64 2.10-2 [50.8 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal/main amd64 libcairo-script-interpreter2 amd64 1.16.0-4ubuntu1 [54.2 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libexpat1-dev amd64 2.2.9-1ubuntu0.4 [117 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 uuid-dev amd64 2.34-0.1ubuntu9.3 [33.6 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal/main amd64 libfontconfig1-dev amd64 2.13.1-2ubuntu3 [731 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal/main amd64 xorg-sgml-doctools all 1:1.11-1 [12.9 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal/main amd64 x11proto-dev all 2019.2-1ubuntu1 [594 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal/main amd64 x11proto-core-dev all 2019.2-1ubuntu1 [2620 B]
# Get:16 http://archive.ubuntu.com/ubuntu focal/main amd64 libxau-dev amd64 1:1.0.9-0ubuntu1 [9552 B]
# Get:17 http://archive.ubuntu.com/ubuntu focal/main amd64 libxdmcp-dev amd64 1:1.1.3-0ubuntu1 [25.3 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal/main amd64 xtrans-dev all 1.4.0-1 [68.9 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal/main amd64 libpthread-stubs0-dev amd64 0.4-1 [5384 B]
# Get:20 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb1-dev amd64 1.14-2 [80.5 kB]
# Get:21 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libx11-dev amd64 2:1.6.9-2ubuntu1.2 [647 kB]
# Get:22 http://archive.ubuntu.com/ubuntu focal/main amd64 libxrender-dev amd64 1:0.9.10-1 [24.9 kB]
# Get:23 http://archive.ubuntu.com/ubuntu focal/main amd64 x11proto-xext-dev all 2019.2-1ubuntu1 [2616 B]
# Get:24 http://archive.ubuntu.com/ubuntu focal/main amd64 libxext-dev amd64 2:1.3.4-0ubuntu1 [82.2 kB]
# Get:25 http://archive.ubuntu.com/ubuntu focal/main amd64 libice-dev amd64 2:1.0.10-0ubuntu1 [47.8 kB]
# Get:26 http://archive.ubuntu.com/ubuntu focal/main amd64 libsm-dev amd64 2:1.2.3-1 [17.0 kB]
# Get:27 http://archive.ubuntu.com/ubuntu focal/main amd64 libpixman-1-dev amd64 0.38.4-0ubuntu1 [243 kB]
# Get:28 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb-render0-dev amd64 1.14-2 [18.4 kB]
# Get:29 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb-shm0-dev amd64 1.14-2 [6716 B]
# Get:30 http://archive.ubuntu.com/ubuntu focal/main amd64 libffi-dev amd64 3.3-4 [57.0 kB]
# Get:31 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglib2.0-dev-bin amd64 2.64.6-1~ubuntu20.04.4 [109 kB]
# Get:32 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libblkid-dev amd64 2.34-0.1ubuntu9.3 [167 kB]
# Get:33 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libmount-dev amd64 2.34-0.1ubuntu9.3 [176 kB]
# Get:34 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpcre16-3 amd64 2:8.39-12ubuntu0.1 [150 kB]
# Get:35 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpcre32-3 amd64 2:8.39-12ubuntu0.1 [140 kB]
# Get:36 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpcrecpp0v5 amd64 2:8.39-12ubuntu0.1 [15.5 kB]
# Get:37 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpcre3-dev amd64 2:8.39-12ubuntu0.1 [540 kB]
# Get:38 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsepol1-dev amd64 3.0-1ubuntu0.1 [325 kB]
# Get:39 http://archive.ubuntu.com/ubuntu focal/main amd64 libpcre2-16-0 amd64 10.34-7 [181 kB]
# Get:40 http://archive.ubuntu.com/ubuntu focal/main amd64 libpcre2-32-0 amd64 10.34-7 [169 kB]
# Get:41 http://archive.ubuntu.com/ubuntu focal/main amd64 libpcre2-posix2 amd64 10.34-7 [5992 B]
# Get:42 http://archive.ubuntu.com/ubuntu focal/main amd64 libpcre2-dev amd64 10.34-7 [670 kB]
# Get:43 http://archive.ubuntu.com/ubuntu focal/main amd64 libselinux1-dev amd64 3.0-1build2 [151 kB]
# Get:44 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglib2.0-dev amd64 2.64.6-1~ubuntu20.04.4 [1506 kB]
# Get:45 http://archive.ubuntu.com/ubuntu focal/main amd64 libcairo2-dev amd64 1.16.0-4ubuntu1 [627 kB]
# Get:46 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpython3.8-dev amd64 3.8.10-0ubuntu1~20.04.5 [3951 kB]
# Fetched 18.6 MB in 3s (6284 kB/s)
# Extracting templates from packages: 100%
#
# (Reading database ... 108827 files and directories currently installed.)
# Preparing to unpack .../0-libpython3.8_3.8.10-0ubuntu1~20.04.5_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking libpython3.8:amd64 (3.8.10-0ubuntu1~20.04.5) over (3.8.10-0ubuntu1~20.04.4) ...
# 7Progress: [  1%] [..........................................................] 8Preparing to unpack .../1-python3.8_3.8.10-0ubuntu1~20.04.5_amd64.deb ...
# Unpacking python3.8 (3.8.10-0ubuntu1~20.04.5) over (3.8.10-0ubuntu1~20.04.4) ...
# 7Progress: [  2%] [#.........................................................] 8Preparing to unpack .../2-libpython3.8-stdlib_3.8.10-0ubuntu1~20.04.5_amd64.deb ...
# Unpacking libpython3.8-stdlib:amd64 (3.8.10-0ubuntu1~20.04.5) over (3.8.10-0ubuntu1~20.04.4) ...
# 7Progress: [  3%] [#.........................................................] 8Preparing to unpack .../3-python3.8-minimal_3.8.10-0ubuntu1~20.04.5_amd64.deb ...
# Unpacking python3.8-minimal (3.8.10-0ubuntu1~20.04.5) over (3.8.10-0ubuntu1~20.04.4) ...
# 7Progress: [  4%] [##........................................................] 8Preparing to unpack .../4-libpython3.8-minimal_3.8.10-0ubuntu1~20.04.5_amd64.deb ...
# Unpacking libpython3.8-minimal:amd64 (3.8.10-0ubuntu1~20.04.5) over (3.8.10-0ubuntu1~20.04.4) ...
# 7Progress: [  5%] [###.......................................................] 8Preparing to unpack .../5-libpcre3_2%3a8.39-12ubuntu0.1_amd64.deb ...
# Unpacking libpcre3:amd64 (2:8.39-12ubuntu0.1) over (2:8.39-12build1) ...
# 7Progress: [  6%] [###.......................................................] 8Setting up libpcre3:amd64 (2:8.39-12ubuntu0.1) ...
# (Reading database ... 108827 files and directories currently installed.).................................] 8(Reading database ...
# Preparing to unpack .../libsepol1_3.0-1ubuntu0.1_amd64.deb ...
# 7Progress: [  8%] [####......................................................] 8Unpacking libsepol1:amd64 (3.0-1ubuntu0.1) over (3.0-1) ...
# Setting up libsepol1:amd64 (3.0-1ubuntu0.1) ...
# 7Progress: [  9%] [#####.....................................................] 8Selecting previously unselected package liblzo2-2:amd64.
# (Reading database ... 108827 files and directories currently installed.)
# Preparing to unpack .../00-liblzo2-2_2.10-2_amd64.deb ...
# 7Progress: [ 10%] [#####.....................................................] 8Unpacking liblzo2-2:amd64 (2.10-2) ...
# Selecting previously unselected package libcairo-script-interpreter2:amd64.
# Preparing to unpack .../01-libcairo-script-interpreter2_1.16.0-4ubuntu1_amd64.deb ...
# 7Progress: [ 11%] [######....................................................] 8Unpacking libcairo-script-interpreter2:amd64 (1.16.0-4ubuntu1) ...
# Selecting previously unselected package libexpat1-dev:amd64.
# Preparing to unpack .../02-libexpat1-dev_2.2.9-1ubuntu0.4_amd64.deb ...
# 7Progress: [ 12%] [#######...................................................] 8Unpacking libexpat1-dev:amd64 (2.2.9-1ubuntu0.4) ...
# Selecting previously unselected package uuid-dev:amd64.
# Preparing to unpack .../03-uuid-dev_2.34-0.1ubuntu9.3_amd64.deb ...
# 7Progress: [ 14%] [#######...................................................] 8Unpacking uuid-dev:amd64 (2.34-0.1ubuntu9.3) ...
# 7Progress: [ 14%] [########..................................................] 8Selecting previously unselected package libfontconfig1-dev:amd64.
# Preparing to unpack .../04-libfontconfig1-dev_2.13.1-2ubuntu3_amd64.deb ...
# Unpacking libfontconfig1-dev:amd64 (2.13.1-2ubuntu3) ...
# 7Progress: [ 15%] [########..................................................] 8Selecting previously unselected package xorg-sgml-doctools.
# Preparing to unpack .../05-xorg-sgml-doctools_1%3a1.11-1_all.deb ...
# Unpacking xorg-sgml-doctools (1:1.11-1) ...
# 7Progress: [ 16%] [#########.................................................] 8Selecting previously unselected package x11proto-dev.
# Preparing to unpack .../06-x11proto-dev_2019.2-1ubuntu1_all.deb ...
# Unpacking x11proto-dev (2019.2-1ubuntu1) ...
# 7Progress: [ 17%] [##########................................................] 8Selecting previously unselected package x11proto-core-dev.
# Preparing to unpack .../07-x11proto-core-dev_2019.2-1ubuntu1_all.deb ...
# Unpacking x11proto-core-dev (2019.2-1ubuntu1) ...
# 7Progress: [ 18%] [##########................................................] 8Selecting previously unselected package libxau-dev:amd64.
# Preparing to unpack .../08-libxau-dev_1%3a1.0.9-0ubuntu1_amd64.deb ...
# Unpacking libxau-dev:amd64 (1:1.0.9-0ubuntu1) ...
# 7Progress: [ 19%] [###########...............................................] 8Selecting previously unselected package libxdmcp-dev:amd64.
# Preparing to unpack .../09-libxdmcp-dev_1%3a1.1.3-0ubuntu1_amd64.deb ...
# 7Progress: [ 20%] [###########...............................................] 8Unpacking libxdmcp-dev:amd64 (1:1.1.3-0ubuntu1) ...
# Selecting previously unselected package xtrans-dev.
# Preparing to unpack .../10-xtrans-dev_1.4.0-1_all.deb ...
# 7Progress: [ 21%] [############..............................................] 8Unpacking xtrans-dev (1.4.0-1) ...
# Selecting previously unselected package libpthread-stubs0-dev:amd64.
# Preparing to unpack .../11-libpthread-stubs0-dev_0.4-1_amd64.deb ...
# 7Progress: [ 22%] [############..............................................] 8Unpacking libpthread-stubs0-dev:amd64 (0.4-1) ...
# Selecting previously unselected package libxcb1-dev:amd64.
# Preparing to unpack .../12-libxcb1-dev_1.14-2_amd64.deb ...
# 7Progress: [ 23%] [#############.............................................] 8Unpacking libxcb1-dev:amd64 (1.14-2) ...
# Selecting previously unselected package libx11-dev:amd64.
# Preparing to unpack .../13-libx11-dev_2%3a1.6.9-2ubuntu1.2_amd64.deb ...
# 7Progress: [ 24%] [##############............................................] 8Unpacking libx11-dev:amd64 (2:1.6.9-2ubuntu1.2) ...
# Selecting previously unselected package libxrender-dev:amd64.
# Preparing to unpack .../14-libxrender-dev_1%3a0.9.10-1_amd64.deb ...
# 7Progress: [ 25%] [##############............................................] 8Unpacking libxrender-dev:amd64 (1:0.9.10-1) ...
# Selecting previously unselected package x11proto-xext-dev.
# Preparing to unpack .../15-x11proto-xext-dev_2019.2-1ubuntu1_all.deb ...
# 7Progress: [ 26%] [###############...........................................] 8Unpacking x11proto-xext-dev (2019.2-1ubuntu1) ...
# 7Progress: [ 27%] [###############...........................................] 8Selecting previously unselected package libxext-dev:amd64.
# Preparing to unpack .../16-libxext-dev_2%3a1.3.4-0ubuntu1_amd64.deb ...
# Unpacking libxext-dev:amd64 (2:1.3.4-0ubuntu1) ...
# 7Progress: [ 28%] [################..........................................] 8Selecting previously unselected package libice-dev:amd64.
# Preparing to unpack .../17-libice-dev_2%3a1.0.10-0ubuntu1_amd64.deb ...
# Unpacking libice-dev:amd64 (2:1.0.10-0ubuntu1) ...
# 7Progress: [ 29%] [################..........................................] 8Selecting previously unselected package libsm-dev:amd64.
# Preparing to unpack .../18-libsm-dev_2%3a1.2.3-1_amd64.deb ...
# Unpacking libsm-dev:amd64 (2:1.2.3-1) ...
# 7Progress: [ 30%] [#################.........................................] 8Selecting previously unselected package libpixman-1-dev:amd64.
# Preparing to unpack .../19-libpixman-1-dev_0.38.4-0ubuntu1_amd64.deb ...
# Unpacking libpixman-1-dev:amd64 (0.38.4-0ubuntu1) ...
# 7Progress: [ 31%] [##################........................................] 8Selecting previously unselected package libxcb-render0-dev:amd64.
# Preparing to unpack .../20-libxcb-render0-dev_1.14-2_amd64.deb ...
# Unpacking libxcb-render0-dev:amd64 (1.14-2) ...
# 7Progress: [ 32%] [##################........................................] 8Selecting previously unselected package libxcb-shm0-dev:amd64.
# Preparing to unpack .../21-libxcb-shm0-dev_1.14-2_amd64.deb ...
# Unpacking libxcb-shm0-dev:amd64 (1.14-2) ...
# 7Progress: [ 34%] [###################.......................................] 8Selecting previously unselected package libffi-dev:amd64.
# Preparing to unpack .../22-libffi-dev_3.3-4_amd64.deb ...
# 7Progress: [ 34%] [###################.......................................] 8Unpacking libffi-dev:amd64 (3.3-4) ...
# Selecting previously unselected package libglib2.0-dev-bin.
# Preparing to unpack .../23-libglib2.0-dev-bin_2.64.6-1~ubuntu20.04.4_amd64.deb ...
# 7Progress: [ 35%] [####################......................................] 8Unpacking libglib2.0-dev-bin (2.64.6-1~ubuntu20.04.4) ...
# Selecting previously unselected package libblkid-dev:amd64.
# Preparing to unpack .../24-libblkid-dev_2.34-0.1ubuntu9.3_amd64.deb ...
# 7Progress: [ 36%] [#####################.....................................] 8Unpacking libblkid-dev:amd64 (2.34-0.1ubuntu9.3) ...
# Selecting previously unselected package libmount-dev:amd64.
# Preparing to unpack .../25-libmount-dev_2.34-0.1ubuntu9.3_amd64.deb ...
# 7Progress: [ 37%] [#####################.....................................] 8Unpacking libmount-dev:amd64 (2.34-0.1ubuntu9.3) ...
# Selecting previously unselected package libpcre16-3:amd64.
# Preparing to unpack .../26-libpcre16-3_2%3a8.39-12ubuntu0.1_amd64.deb ...
# 7Progress: [ 38%] [######################....................................] 8Unpacking libpcre16-3:amd64 (2:8.39-12ubuntu0.1) ...
# Selecting previously unselected package libpcre32-3:amd64.
# Preparing to unpack .../27-libpcre32-3_2%3a8.39-12ubuntu0.1_amd64.deb ...
# 7Progress: [ 39%] [######################....................................] 8Unpacking libpcre32-3:amd64 (2:8.39-12ubuntu0.1) ...
# 7Progress: [ 40%] [#######################...................................] 8Selecting previously unselected package libpcrecpp0v5:amd64.
# Preparing to unpack .../28-libpcrecpp0v5_2%3a8.39-12ubuntu0.1_amd64.deb ...
# Unpacking libpcrecpp0v5:amd64 (2:8.39-12ubuntu0.1) ...
# 7Progress: [ 41%] [#######################...................................] 8Selecting previously unselected package libpcre3-dev:amd64.
# Preparing to unpack .../29-libpcre3-dev_2%3a8.39-12ubuntu0.1_amd64.deb ...
# Unpacking libpcre3-dev:amd64 (2:8.39-12ubuntu0.1) ...
# 7Progress: [ 42%] [########################..................................] 8Selecting previously unselected package libsepol1-dev:amd64.
# Preparing to unpack .../30-libsepol1-dev_3.0-1ubuntu0.1_amd64.deb ...
# Unpacking libsepol1-dev:amd64 (3.0-1ubuntu0.1) ...
# 7Progress: [ 43%] [#########################.................................] 8Selecting previously unselected package libpcre2-16-0:amd64.
# Preparing to unpack .../31-libpcre2-16-0_10.34-7_amd64.deb ...
# Unpacking libpcre2-16-0:amd64 (10.34-7) ...
# 7Progress: [ 44%] [#########################.................................] 8Selecting previously unselected package libpcre2-32-0:amd64.
# Preparing to unpack .../32-libpcre2-32-0_10.34-7_amd64.deb ...
# Unpacking libpcre2-32-0:amd64 (10.34-7) ...
# 7Progress: [ 45%] [##########################................................] 8Selecting previously unselected package libpcre2-posix2:amd64.
# Preparing to unpack .../33-libpcre2-posix2_10.34-7_amd64.deb ...
# Unpacking libpcre2-posix2:amd64 (10.34-7) ...
# 7Progress: [ 46%] [##########################................................] 8Selecting previously unselected package libpcre2-dev:amd64.
# Preparing to unpack .../34-libpcre2-dev_10.34-7_amd64.deb ...
# 7Progress: [ 47%] [###########################...............................] 8Unpacking libpcre2-dev:amd64 (10.34-7) ...
# Selecting previously unselected package libselinux1-dev:amd64.
# Preparing to unpack .../35-libselinux1-dev_3.0-1build2_amd64.deb ...
# 7Progress: [ 48%] [###########################...............................] 8Unpacking libselinux1-dev:amd64 (3.0-1build2) ...
# Selecting previously unselected package libglib2.0-dev:amd64.
# Preparing to unpack .../36-libglib2.0-dev_2.64.6-1~ubuntu20.04.4_amd64.deb ...
# 7Progress: [ 49%] [############################..............................] 8Unpacking libglib2.0-dev:amd64 (2.64.6-1~ubuntu20.04.4) ...
# Selecting previously unselected package libcairo2-dev:amd64.
# Preparing to unpack .../37-libcairo2-dev_1.16.0-4ubuntu1_amd64.deb ...
# Unpacking libcairo2-dev:amd64 (1.16.0-4ubuntu1) ...
# 7Progress: [ 50%] [#############################.............................] 8Selecting previously unselected package libpython3.8-dev:amd64.
# Preparing to unpack .../38-libpython3.8-dev_3.8.10-0ubuntu1~20.04.5_amd64.deb ...
# Unpacking libpython3.8-dev:amd64 (3.8.10-0ubuntu1~20.04.5) ...
# 7Progress: [ 51%] [#############################.............................] 8Setting up libpcrecpp0v5:amd64 (2:8.39-12ubuntu0.1) ...
# 7Progress: [ 52%] [##############################............................] 8Setting up libglib2.0-dev-bin (2.64.6-1~ubuntu20.04.4) ...
# 7Progress: [ 53%] [###############################...........................] 8Setting up libpython3.8-minimal:amd64 (3.8.10-0ubuntu1~20.04.5) ...
# 7Progress: [ 54%] [###############################...........................] 8Setting up libpixman-1-dev:amd64 (0.38.4-0ubuntu1) ...
# 7Progress: [ 55%] [###############################...........................] 8Setting up libpcre16-3:amd64 (2:8.39-12ubuntu0.1) ...
# 7Progress: [ 56%] [################################..........................] 8Setting up libsepol1-dev:amd64 (3.0-1ubuntu0.1) ...
# 7Progress: [ 57%] [#################################.........................] 8Setting up liblzo2-2:amd64 (2.10-2) ...
# 7Progress: [ 58%] [#################################.........................] 8Setting up libffi-dev:amd64 (3.3-4) ...
# 7Progress: [ 59%] [##################################........................] 8Setting up libpthread-stubs0-dev:amd64 (0.4-1) ...
# 7Progress: [ 60%] [###################################.......................] 8Setting up libpcre2-16-0:amd64 (10.34-7) ...
# 7Progress: [ 61%] [###################################.......................] 87Progress: [ 62%] [###################################.......................] 8Setting up xtrans-dev (1.4.0-1) ...
# 7Progress: [ 63%] [####################################......................] 8Setting up libpcre2-32-0:amd64 (10.34-7) ...
# 7Progress: [ 64%] [#####################################.....................] 8Setting up libexpat1-dev:amd64 (2.2.9-1ubuntu0.4) ...
# 7Progress: [ 65%] [#####################################.....................] 8Setting up uuid-dev:amd64 (2.34-0.1ubuntu9.3) ...
# 7Progress: [ 66%] [######################################....................] 8Setting up libpcre32-3:amd64 (2:8.39-12ubuntu0.1) ...
# 7Progress: [ 67%] [#######################################...................] 8Setting up libpcre2-posix2:amd64 (10.34-7) ...
# 7Progress: [ 68%] [#######################################...................] 8Setting up python3.8-minimal (3.8.10-0ubuntu1~20.04.5) ...
# 7Progress: [ 70%] [########################################..................] 8Setting up xorg-sgml-doctools (1:1.11-1) ...
# 7Progress: [ 70%] [########################################..................] 8Setting up libpython3.8-stdlib:amd64 (3.8.10-0ubuntu1~20.04.5) ...
# 7Progress: [ 71%] [#########################################.................] 8Setting up python3.8 (3.8.10-0ubuntu1~20.04.5) ...
# 7Progress: [ 72%] [#########################################.................] 8Setting up x11proto-dev (2019.2-1ubuntu1) ...
# 7Progress: [ 73%] [##########################################................] 8Setting up libcairo-script-interpreter2:amd64 (1.16.0-4ubuntu1) ...
# 7Progress: [ 74%] [###########################################...............] 8Setting up libblkid-dev:amd64 (2.34-0.1ubuntu9.3) ...
# 7Progress: [ 75%] [###########################################...............] 8Setting up libfontconfig1-dev:amd64 (2.13.1-2ubuntu3) ...
# 7Progress: [ 76%] [############################################..............] 87Progress: [ 77%] [############################################..............] 8Setting up libxau-dev:amd64 (1:1.0.9-0ubuntu1) ...
# 7Progress: [ 78%] [#############################################.............] 8Setting up libpcre2-dev:amd64 (10.34-7) ...
# 7Progress: [ 79%] [#############################################.............] 8Setting up libice-dev:amd64 (2:1.0.10-0ubuntu1) ...
# 7Progress: [ 80%] [##############################################............] 8Setting up libsm-dev:amd64 (2:1.2.3-1) ...
# 7Progress: [ 81%] [###############################################...........] 8Setting up libselinux1-dev:amd64 (3.0-1build2) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up libpcre3-dev:amd64 (2:8.39-12ubuntu0.1) ...
# 7Progress: [ 83%] [################################################..........] 8Setting up libxdmcp-dev:amd64 (1:1.1.3-0ubuntu1) ...
# 7Progress: [ 84%] [#################################################.........] 8Setting up x11proto-core-dev (2019.2-1ubuntu1) ...
# 7Progress: [ 85%] [#################################################.........] 8Setting up libpython3.8:amd64 (3.8.10-0ubuntu1~20.04.5) ...
# 7Progress: [ 86%] [#################################################.........] 8Setting up x11proto-xext-dev (2019.2-1ubuntu1) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up libmount-dev:amd64 (2.34-0.1ubuntu9.3) ...
# 7Progress: [ 88%] [###################################################.......] 8Setting up libxcb1-dev:amd64 (1.14-2) ...
# 7Progress: [ 89%] [###################################################.......] 8Setting up libx11-dev:amd64 (2:1.6.9-2ubuntu1.2) ...
# 7Progress: [ 90%] [####################################################......] 8Setting up libxcb-shm0-dev:amd64 (1.14-2) ...
# 7Progress: [ 91%] [#####################################################.....] 8Setting up libglib2.0-dev:amd64 (2.64.6-1~ubuntu20.04.4) ...
# 7Progress: [ 93%] [#####################################################.....] 8Setting up libpython3.8-dev:amd64 (3.8.10-0ubuntu1~20.04.5) ...
# 7Progress: [ 93%] [#####################################################.....] 8Setting up libxcb-render0-dev:amd64 (1.14-2) ...
# 7Progress: [ 94%] [######################################################....] 8Setting up libxext-dev:amd64 (2:1.3.4-0ubuntu1) ...
# 7Progress: [ 95%] [#######################################################...] 8Setting up libxrender-dev:amd64 (1:0.9.10-1) ...
# 7Progress: [ 96%] [#######################################################...] 8Processing triggers for install-info (6.7.0.dfsg.2-5) ...
# Processing triggers for mime-support (3.64ubuntu1) ...
# Processing triggers for libglib2.0-0:amd64 (2.64.6-1~ubuntu20.04.4) ...
# 7Progress: [ 97%] [########################################################..] 87Progress: [ 98%] [#########################################################.] 8Processing triggers for libc-bin (2.31-0ubuntu9.7) ...
# Processing triggers for man-db (2.9.1-1) ...
# Setting up libcairo2-dev:amd64 (1.16.0-4ubuntu1) ...
# 7Progress: [ 99%] [#########################################################.] 8
# 78^C

# %% [markdown]
# # 克隆NNSVS训练套件

# %%
# !git clone https://github.com/Erythrocyte3803/enunu_training_kit.git

# %% [markdown]
# # 复制歌唱数据集到指定目录

# %%
singer = 'nnsvs-test'
# !cp ../input/$singer/* ./enunu_training_kit/train/singing_database

# %% [markdown]
# # 开始训练

# %%
# !sudo bash ./enunu_training_kit/train/run.sh

# %% [markdown]
# # 准备下载

# %%
# !zip -r model.zip ./enunu_training_kit/train/singing_database/exp

# %% [markdown]
# # 下载完成

# %%
# !rm model.zip
